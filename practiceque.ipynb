# %%
#tax amount calc
meal_cost = float(input("Enter the cost of the meal: $"))

tax_rate = 0.13

tax_amount = meal_cost * tax_rate
tip_amount = meal_cost * 0.18
total_amount = meal_cost + tax_amount + tip_amount

print("Tax: ${:.2f}".format(tax_amount))
print("Tip: ${:.2f}".format(tip_amount))
print("Total: ${:.2f}".format(total_amount))
# Out:
# Enter the cost of the meal: $200
# Tax: $26.00
# Tip: $36.00
# Total: $262.00

# %%
name="Sarthak Khatal"
mailingaddress="sarthak78t@gmail.com"
print("my name is:{name} and my mailing address is: {email}".format(name=name,email=mailingaddress));
# Out:
# my name is:Sarthak Khatal and my mailing address is: sarthak78t@gmail.com

# %%
Name=input("Enter yout name:")
print("hello {Name}".format(Name=Name))
# Out:
# Enter yout name:Sarthak
# hello Sarthak

# %%
width = float(input("Enter the width of the room: "))
height = float(input("Enter the height of the room: "))
area = width * height
print("The width of the room  {width} and the height of the room is {height}, ""then the total area of the room is {area} m".format(width=width, height=height, area=area)
)
# Out:
# Enter the width of the room: 32
# Enter the height of the room: 50
# The width of the room  32.0 and the height of the room is 50.0, then the total area of the room is 1600.0 m

# %%
sqacre = 43560

length = float(input("Enter the length of the field in feet: "))
width = float(input("Enter the width of the field in feet: "))
area = (length * width) / sqacre
print("The length of the field in feet is {length}, ""the width of the field in feet is {width}, ""and the area of the field in acres is {area}".format(length=length, width=width, area=area))
# Out:
# Enter the length of the field in feet: 90
# Enter the width of the field in feet: 50
# The length of the field in feet is 90.0, the width of the field in feet is 50.0, and the area of the field in acres is 0.10330578512396695

# %%
number=int(input("Enter the first n natural number:"))
sum=number*number+1/2
print(f"the sum of the first natural number is:{sum}")
# Out:
# Enter the first n natural number:5
# the sum of the first natural number is:25.5

# %%
widgets = int(input("Enter the number of widgets: "))
gizmos = int(input("Enter the number of gizmos: "))

widget_weight = 75
gizmo_weight = 112

total_weight = (widgets * widget_weight) + (gizmos * gizmo_weight)

print(f"The total weight of the order is {total_weight} grams.")
# Out:
# Enter the number of widgets: 8
# Enter the number of gizmos: 9
# The total weight of the order is 1608 grams.
